# %% [markdown]
# # Trees

# %% [markdown]
# ### The last data structure we’ll cover in this lesson is the tree. Trees are a bit different than the data structures we’ve seen thus far, but present a useful way for storing information that has either a hierarchical structure or that needs to be rapidly searchable. The most distinguishing trait of trees, however, is their sheer flexibility. We’ll explain what we mean below.

# %% [markdown]
# ## What is a tree?

# %%
class Node:
    def __init__(self, val):
        self.left = None
        self.right = None
        self.val = val

# %%
A = root = Node(100)

B = root.left = Node(95)
C = root.right = Node(90)

D = root.left.left = Node(85)
E = root.left.right = Node(75)

F = root.right.left = Node(80)
G = root.right.right = Node(70)

H = root.left.left.left = Node(65)
I = root.left.left.right = Node(55)

J = root.left.right.left = Node(45)
K = root.left.right.right = Node(35)

L = root.right.left.left = Node(60)
M = root.right.left.right = Node(50)

# %%
# Establish the initial root node and children
root = Node('A')
root.left = Node('B')
root.right = Node('C')

# Add the appropriate children for ‘B’ and ‘C’
root.left.left = Node('D')
root.left.right = Node('E')
root.right.left = Node('F')
root.right.right = Node('G')

# %%
def preorder(tree):
    if tree:
        print(tree.getRootVal())
        preorder(tree.getLeftChild())
        preorder(tree.getRightChild())

# %%
def preorder(self):
    print(self.key)
    if self.leftChild:
        self.leftChild.preorder()
    if self.rightChild:
        self.rightChild.preorder()

# %%
def postorder(tree):
    if tree != None:
        postorder(tree.getLeftChild())
        postorder(tree.getRightChild())
        print(tree.getRootVal())

# %%
def postordereval(tree):
    opers = {'+':operator.add, '-':operator.sub, '*':operator.mul, '/':operator.truediv}
    res1 = None
    res2 = None
    if tree:
        res1 = postordereval(tree.getLeftChild())
        res2 = postordereval(tree.getRightChild())
        if res1 and res2:
            return opers[tree.getRootVal()](res1,res2)
        else:
            return tree.getRootVal()

# %%
def inorder(tree):
  if tree != None:
      inorder(tree.getLeftChild())
      print(tree.getRootVal())
      inorder(tree.getRightChild())

# %%
def printexp(tree):
  sVal = ""
  if tree:
      sVal = '(' + printexp(tree.getLeftChild())
      sVal = sVal + str(tree.getRootVal())
      sVal = sVal + printexp(tree.getRightChild())+')'
  return sVal

# %%
Traversing Directory Trees in Python

# %%
# Import the os module, for the os.walk function
import os
 
# Set the directory you want to start from
rootDir = '.'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
# Out:
# Found directory: .
# 	.DS_Store
# 	0A32eTdBKayjCWhZqDOQ.asm
# 	0A32eTdBKayjCWhZqDOQ.bytes
# 	0ACDbR5M3ZhBJajygTuf.asm
# 	0ACDbR5M3ZhBJajygTuf.bytes
# 	2006.csv.bz2
# 	2008.csv
# 	2008.csv.bz2
# 	2013-10-01_capture-win12.netflow.csv
# 	2013-10-01_capture-win8.netflow.csv
# 	2015-07-28_mixed.binetflow.before.cvs.infection
# 	2015-09-08_mixed.binetflow.after.csv
# 	2015-09-08_mixed.binetflow.after.htm
# 	2015-09-08_mixed.binetflow.before.csv
# 	2015-09-08_mixed.binetflow.before.htm
# 	2015-09-08_mixed.binetflow.CSV
# 	A B Tests.ipynb
# 	Aggregating_and_grouping.ipynb
# 	Airline Arrivals.ipynb
# 	amazon_cells_labelled.txt
# 	APCspend2013.csv
# 	Bias and A A Testing.ipynb
# 	Bikeshare-Data.zip
# 	BikeShare.zip
# 	BOSTON_MARATHON_REVIEW.CSV
# 	botnet-capture-20110810-neris.pcap
# 	Boxes.JPG
# 	Capstone Analytic Report and Research Proposal.ipynb
# 	cat - with hidden data.bmp
# 	cat.jpg
# 	Cat_with_hidden_file.bmp
# 	Challenge
# 	Challenge - Data cleaning & Validation.ipynb
# 	Challenge - If a tree falls in the forest.ipynb
# 	Challenge - Make your own regression model - Linear Regression.ipynb
# 	Challenge - Validating a linear regression.ipynb
# 	Challenge - What model can answer this question.ipynb
# 	Challenge Advanced Regression.ipynb
# 	Challenge Boston Marathon.ipynb
# 	Challenge Evaluate an Experiment Analysis.ipynb
# 	Challenge Feedback Analysis-Copy2.ipynb
# 	Challenge Feedback Analysis.ipynb
# 	Challenge Iterate and evaluate your classifier.ipynb
# 	Challenge Make your own regression model.ipynb
# 	Challenge Model Comparison - Botnet.ipynb
# 	Challenge Preparing a Dataset for Modeling.ipynb
# 	code.zip
# 	Computer_security_data_set.csv
# 	Credit Cards.ipynb
# 	creditcard.csv
# 	creditcardfraud.zip
# 	cs448b_ipasn.csv
# 	database.sqlite
# 	dataSample.7z
# 	Dimensionality Reduction in Linear Regression.ipynb
# 	documentation.pdf
# 	Drill - Unsupervised or Supervised.ipynb
# 	Drill Fixing assumptions.ipynb
# 	Drill Formulating Good Research Questions.ipynb
# 	Drill Regression or Classification.ipynb
# 	epicurious-recipes-with-rating-and-nutrition.zip
# 	epi_r.csv
# 	fastStorage.zip
# 	Formatting_subplots_and_seaborn.ipynb
# 	Fourier Transform in Numpy.ipynb
# 	full_format_recipes.json
# 	Gradient Descent Algorithm.ipynb
# 	Guided example and challenge boosting models.ipynb
# 	Guided example and Challenge.ipynb
# 	Housing Prices.ipynb
# 	imdb_labelled.txt
# 	iris-species.zip
# 	Iris.csv
# 	Iris.ipynb
# 	Joins and CTEs.ipynb
# 	K Nearest Nieghbor Classifier.ipynb
# 	K Nearest Nieghbor Regression.ipynb
# 	K-Means.ipynb
# 	Keys.jpg
# 	Lasso Regression.ipynb
# 	lightning.JPG
# 	LoanStats3a.csv.zip
# 	LoanStats3d.csv.zip
# 	LoanStats3dd.csv
# 	melbourne-housing-market.zip
# 	MELBOURNE_HOUSE_PRICES_LESS.csv
# 	Melbourne_housing_FULL.csv
# 	Multivariable_regression-Copy1.ipynb
# 	Multivariable_regression.ipynb
# 	Other methods – mean-shift, spectral, affinity.ipynb
# 	pcapdata.py
# 	Phishing_Websites_Features.docx
# 	Phishing_website_data_set.arff
# 	Phishing_website_data_set.txt
# 	Random Forest Guided Example.ipynb
# 	Readme_file.docx
# 	recipe.py
# 	reviews_Books_5.json.gz
# 	rnd.zip
# 	sampleSubmission.csv
# 	sentiment labelled sentences.zip
# 	Sort in 60 Minutes.ipynb
# 	stations.sql
# 	status.sql
# 	Supervised Neural Nets.ipynb
# 	table_8_offenses_known_to_law_enforcement_illinois_by_city_2013.xls
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls
# 	TDLAS Drill
# 	The_basics_of_plotting_review.ipynb
# 	Thinkful Random Forest Guided Example.ipynb
# 	trainLabels.csv
# 	Trees.ipynb
# 	trips.sql
# 	Tuning K Nearest Nieghbor.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled10.ipynb
# 	Untitled11.ipynb
# 	Untitled12.ipynb
# 	Untitled13.ipynb
# 	Untitled14.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
# 	Untitled5.ipynb
# 	Untitled6.ipynb
# 	Untitled7.ipynb
# 	Untitled8.ipynb
# 	Untitled9.ipynb
# 	utils.py
# 	VerticleLines.JPG
# 	Visualization Challenge - Data cleaning & validation-Copy1.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy2.ipynb
# 	Visualization Challenge - Data cleaning & validation.ipynb
# 	weather.sql
# 	WELLCOME.zip
# 	WELLCOME_APCspend2013_forThinkful.csv
# 	yelp_labelled.txt
# Found directory: .\.ipynb_checkpoints
# 	A B Tests-checkpoint.ipynb
# 	Aggregating_and_grouping-checkpoint.ipynb
# 	Airline Arrivals-checkpoint.ipynb
# 	Bias and A A Testing-checkpoint.ipynb
# 	Capstone Analytic Report and Research Proposal-checkpoint.ipynb
# 	Challenge
# 	Challenge - Data cleaning & Validation-checkpoint.ipynb
# 	Challenge - If a tree falls in the forest-checkpoint.ipynb
# 	Challenge - Make your own regression model - Linear Regression-checkpoint.ipynb
# 	Challenge - Validating a linear regression-checkpoint.ipynb
# 	Challenge - What model can answer this question-checkpoint.ipynb
# 	Challenge Advanced Regression-checkpoint.ipynb
# 	Challenge Boston Marathon-checkpoint.ipynb
# 	Challenge Evaluate an Experiment Analysis-checkpoint.ipynb
# 	Challenge Feedback Analysis-checkpoint.ipynb
# 	Challenge Feedback Analysis-Copy2-checkpoint.ipynb
# 	Challenge Iterate and evaluate your classifier-checkpoint.ipynb
# 	Challenge Make your own regression model-checkpoint.ipynb
# 	Challenge Model Comparison - Botnet-checkpoint.ipynb
# 	Challenge Preparing a Dataset for Modeling-checkpoint.ipynb
# 	Credit Cards-checkpoint.ipynb
# 	Dimensionality Reduction in Linear Regression-checkpoint.ipynb
# 	Drill - Unsupervised or Supervised-checkpoint.ipynb
# 	Drill Fixing assumptions-checkpoint.ipynb
# 	Drill Formulating Good Research Questions-checkpoint.ipynb
# 	Formatting_subplots_and_seaborn-checkpoint.ipynb
# 	Fourier Transform in Numpy-checkpoint.ipynb
# 	Gradient Descent Algorithm-checkpoint.ipynb
# 	Guided example and challenge boosting models-checkpoint.ipynb
# 	Guided example and Challenge-checkpoint.ipynb
# 	Housing Prices-checkpoint.ipynb
# 	Iris-checkpoint.ipynb
# 	Joins and CTEs-checkpoint.ipynb
# 	K Nearest Nieghbor Classifier-checkpoint.ipynb
# 	K Nearest Nieghbor Regression-checkpoint.ipynb
# 	K-Means-checkpoint.ipynb
# 	Lasso Regression-checkpoint.ipynb
# 	Multivariable_regression-checkpoint.ipynb
# 	Multivariable_regression-Copy1-checkpoint.ipynb
# 	Other methods – mean-shift, spectral, affinity-checkpoint.ipynb
# 	Random Forest Guided Example-checkpoint.ipynb
# 	Sort in 60 Minutes-checkpoint.ipynb
# 	Supervised Neural Nets-checkpoint.ipynb
# 	The_basics_of_plotting_review-checkpoint.ipynb
# 	Thinkful Random Forest Guided Example-checkpoint.ipynb
# 	Trees-checkpoint.ipynb
# 	Tuning K Nearest Nieghbor-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# 	Untitled1-checkpoint.ipynb
# 	Untitled10-checkpoint.ipynb
# 	Untitled11-checkpoint.ipynb
# 	Untitled12-checkpoint.ipynb
# 	Untitled13-checkpoint.ipynb
# 	Untitled14-checkpoint.ipynb
# 	Untitled2-checkpoint.ipynb
# 	Untitled3-checkpoint.ipynb
# 	Untitled4-checkpoint.ipynb
# 	Untitled5-checkpoint.ipynb
# 	Untitled6-checkpoint.ipynb
# 	Untitled7-checkpoint.ipynb
# 	Untitled8-checkpoint.ipynb
# 	Untitled9-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy1-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy2-checkpoint.ipynb
# Found directory: .\2006.csv
# 	2006.csv
# Found directory: .\CYB642
# 	FdSig-master.zip
# Found directory: .\CYB642\FdSig-master
# Found directory: .\CYB642\FdSig-master\FdSig-master
# 	cat.jpg
# 	deco.jpg
# 	FdSig.py
# 	new-new.jpg.jpg
# 	new.jpg
# 	ReadMe.md
# 	sc_img.png
# 	sc_text_secret.png
# 	Secret.JPG
# Found directory: .\LoanStats3a.csv
# Found directory: .\LoanStats3d.csv
# Found directory: .\Malware Project
# 	An empirical comparison of botnet detection methods.pdf
# 	capture20110810.csv
# 	capture20110810.htm
# 	Malware Project.ipynb
# 	Untitled.ipynb
# Found directory: .\Malware Project\.ipynb_checkpoints
# 	Malware Project-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# Found directory: .\sentiment labelled sentences
# 	.DS_Store
# 	readme.txt
# Found directory: .\__MACOSX
# 	._sentiment labelled sentences
# Found directory: .\__MACOSX\sentiment labelled sentences
# 	._.DS_Store
# 	._imdb_labelled.txt
# 	._readme.txt

# %%
import os
 
rootDir = '.'
for dirName, subdirList, fileList in os.walk(rootDir, topdown=False):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
# Out:
# Found directory: .\.ipynb_checkpoints
# 	A B Tests-checkpoint.ipynb
# 	Aggregating_and_grouping-checkpoint.ipynb
# 	Airline Arrivals-checkpoint.ipynb
# 	Bias and A A Testing-checkpoint.ipynb
# 	Capstone Analytic Report and Research Proposal-checkpoint.ipynb
# 	Challenge
# 	Challenge - Data cleaning & Validation-checkpoint.ipynb
# 	Challenge - If a tree falls in the forest-checkpoint.ipynb
# 	Challenge - Make your own regression model - Linear Regression-checkpoint.ipynb
# 	Challenge - Validating a linear regression-checkpoint.ipynb
# 	Challenge - What model can answer this question-checkpoint.ipynb
# 	Challenge Advanced Regression-checkpoint.ipynb
# 	Challenge Boston Marathon-checkpoint.ipynb
# 	Challenge Evaluate an Experiment Analysis-checkpoint.ipynb
# 	Challenge Feedback Analysis-checkpoint.ipynb
# 	Challenge Feedback Analysis-Copy2-checkpoint.ipynb
# 	Challenge Iterate and evaluate your classifier-checkpoint.ipynb
# 	Challenge Make your own regression model-checkpoint.ipynb
# 	Challenge Model Comparison - Botnet-checkpoint.ipynb
# 	Challenge Preparing a Dataset for Modeling-checkpoint.ipynb
# 	Credit Cards-checkpoint.ipynb
# 	Dimensionality Reduction in Linear Regression-checkpoint.ipynb
# 	Drill - Unsupervised or Supervised-checkpoint.ipynb
# 	Drill Fixing assumptions-checkpoint.ipynb
# 	Drill Formulating Good Research Questions-checkpoint.ipynb
# 	Formatting_subplots_and_seaborn-checkpoint.ipynb
# 	Fourier Transform in Numpy-checkpoint.ipynb
# 	Gradient Descent Algorithm-checkpoint.ipynb
# 	Guided example and challenge boosting models-checkpoint.ipynb
# 	Guided example and Challenge-checkpoint.ipynb
# 	Housing Prices-checkpoint.ipynb
# 	Iris-checkpoint.ipynb
# 	Joins and CTEs-checkpoint.ipynb
# 	K Nearest Nieghbor Classifier-checkpoint.ipynb
# 	K Nearest Nieghbor Regression-checkpoint.ipynb
# 	K-Means-checkpoint.ipynb
# 	Lasso Regression-checkpoint.ipynb
# 	Multivariable_regression-checkpoint.ipynb
# 	Multivariable_regression-Copy1-checkpoint.ipynb
# 	Other methods – mean-shift, spectral, affinity-checkpoint.ipynb
# 	Random Forest Guided Example-checkpoint.ipynb
# 	Sort in 60 Minutes-checkpoint.ipynb
# 	Supervised Neural Nets-checkpoint.ipynb
# 	The_basics_of_plotting_review-checkpoint.ipynb
# 	Thinkful Random Forest Guided Example-checkpoint.ipynb
# 	Trees-checkpoint.ipynb
# 	Tuning K Nearest Nieghbor-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# 	Untitled1-checkpoint.ipynb
# 	Untitled10-checkpoint.ipynb
# 	Untitled11-checkpoint.ipynb
# 	Untitled12-checkpoint.ipynb
# 	Untitled13-checkpoint.ipynb
# 	Untitled14-checkpoint.ipynb
# 	Untitled2-checkpoint.ipynb
# 	Untitled3-checkpoint.ipynb
# 	Untitled4-checkpoint.ipynb
# 	Untitled5-checkpoint.ipynb
# 	Untitled6-checkpoint.ipynb
# 	Untitled7-checkpoint.ipynb
# 	Untitled8-checkpoint.ipynb
# 	Untitled9-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy1-checkpoint.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy2-checkpoint.ipynb
# Found directory: .\2006.csv
# 	2006.csv
# Found directory: .\CYB642\FdSig-master\FdSig-master
# 	cat.jpg
# 	deco.jpg
# 	FdSig.py
# 	new-new.jpg.jpg
# 	new.jpg
# 	ReadMe.md
# 	sc_img.png
# 	sc_text_secret.png
# 	Secret.JPG
# Found directory: .\CYB642\FdSig-master
# Found directory: .\CYB642
# 	FdSig-master.zip
# Found directory: .\LoanStats3a.csv
# Found directory: .\LoanStats3d.csv
# Found directory: .\Malware Project\.ipynb_checkpoints
# 	Malware Project-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# Found directory: .\Malware Project
# 	An empirical comparison of botnet detection methods.pdf
# 	capture20110810.csv
# 	capture20110810.htm
# 	Malware Project.ipynb
# 	Untitled.ipynb
# Found directory: .\sentiment labelled sentences
# 	.DS_Store
# 	readme.txt
# Found directory: .\__MACOSX\sentiment labelled sentences
# 	._.DS_Store
# 	._imdb_labelled.txt
# 	._readme.txt
# Found directory: .\__MACOSX
# 	._sentiment labelled sentences
# Found directory: .
# 	.DS_Store
# 	0A32eTdBKayjCWhZqDOQ.asm
# 	0A32eTdBKayjCWhZqDOQ.bytes
# 	0ACDbR5M3ZhBJajygTuf.asm
# 	0ACDbR5M3ZhBJajygTuf.bytes
# 	2006.csv.bz2
# 	2008.csv
# 	2008.csv.bz2
# 	2013-10-01_capture-win12.netflow.csv
# 	2013-10-01_capture-win8.netflow.csv
# 	2015-07-28_mixed.binetflow.before.cvs.infection
# 	2015-09-08_mixed.binetflow.after.csv
# 	2015-09-08_mixed.binetflow.after.htm
# 	2015-09-08_mixed.binetflow.before.csv
# 	2015-09-08_mixed.binetflow.before.htm
# 	2015-09-08_mixed.binetflow.CSV
# 	A B Tests.ipynb
# 	Aggregating_and_grouping.ipynb
# 	Airline Arrivals.ipynb
# 	amazon_cells_labelled.txt
# 	APCspend2013.csv
# 	Bias and A A Testing.ipynb
# 	Bikeshare-Data.zip
# 	BikeShare.zip
# 	BOSTON_MARATHON_REVIEW.CSV
# 	botnet-capture-20110810-neris.pcap
# 	Boxes.JPG
# 	Capstone Analytic Report and Research Proposal.ipynb
# 	cat - with hidden data.bmp
# 	cat.jpg
# 	Cat_with_hidden_file.bmp
# 	Challenge
# 	Challenge - Data cleaning & Validation.ipynb
# 	Challenge - If a tree falls in the forest.ipynb
# 	Challenge - Make your own regression model - Linear Regression.ipynb
# 	Challenge - Validating a linear regression.ipynb
# 	Challenge - What model can answer this question.ipynb
# 	Challenge Advanced Regression.ipynb
# 	Challenge Boston Marathon.ipynb
# 	Challenge Evaluate an Experiment Analysis.ipynb
# 	Challenge Feedback Analysis-Copy2.ipynb
# 	Challenge Feedback Analysis.ipynb
# 	Challenge Iterate and evaluate your classifier.ipynb
# 	Challenge Make your own regression model.ipynb
# 	Challenge Model Comparison - Botnet.ipynb
# 	Challenge Preparing a Dataset for Modeling.ipynb
# 	code.zip
# 	Computer_security_data_set.csv
# 	Credit Cards.ipynb
# 	creditcard.csv
# 	creditcardfraud.zip
# 	cs448b_ipasn.csv
# 	database.sqlite
# 	dataSample.7z
# 	Dimensionality Reduction in Linear Regression.ipynb
# 	documentation.pdf
# 	Drill - Unsupervised or Supervised.ipynb
# 	Drill Fixing assumptions.ipynb
# 	Drill Formulating Good Research Questions.ipynb
# 	Drill Regression or Classification.ipynb
# 	epicurious-recipes-with-rating-and-nutrition.zip
# 	epi_r.csv
# 	fastStorage.zip
# 	Formatting_subplots_and_seaborn.ipynb
# 	Fourier Transform in Numpy.ipynb
# 	full_format_recipes.json
# 	Gradient Descent Algorithm.ipynb
# 	Guided example and challenge boosting models.ipynb
# 	Guided example and Challenge.ipynb
# 	Housing Prices.ipynb
# 	imdb_labelled.txt
# 	iris-species.zip
# 	Iris.csv
# 	Iris.ipynb
# 	Joins and CTEs.ipynb
# 	K Nearest Nieghbor Classifier.ipynb
# 	K Nearest Nieghbor Regression.ipynb
# 	K-Means.ipynb
# 	Keys.jpg
# 	Lasso Regression.ipynb
# 	lightning.JPG
# 	LoanStats3a.csv.zip
# 	LoanStats3d.csv.zip
# 	LoanStats3dd.csv
# 	melbourne-housing-market.zip
# 	MELBOURNE_HOUSE_PRICES_LESS.csv
# 	Melbourne_housing_FULL.csv
# 	Multivariable_regression-Copy1.ipynb
# 	Multivariable_regression.ipynb
# 	Other methods – mean-shift, spectral, affinity.ipynb
# 	pcapdata.py
# 	Phishing_Websites_Features.docx
# 	Phishing_website_data_set.arff
# 	Phishing_website_data_set.txt
# 	Random Forest Guided Example.ipynb
# 	Readme_file.docx
# 	recipe.py
# 	reviews_Books_5.json.gz
# 	rnd.zip
# 	sampleSubmission.csv
# 	sentiment labelled sentences.zip
# 	Sort in 60 Minutes.ipynb
# 	stations.sql
# 	status.sql
# 	Supervised Neural Nets.ipynb
# 	table_8_offenses_known_to_law_enforcement_illinois_by_city_2013.xls
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls
# 	TDLAS Drill
# 	The_basics_of_plotting_review.ipynb
# 	Thinkful Random Forest Guided Example.ipynb
# 	trainLabels.csv
# 	Trees.ipynb
# 	trips.sql
# 	Tuning K Nearest Nieghbor.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled10.ipynb
# 	Untitled11.ipynb
# 	Untitled12.ipynb
# 	Untitled13.ipynb
# 	Untitled14.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
# 	Untitled5.ipynb
# 	Untitled6.ipynb
# 	Untitled7.ipynb
# 	Untitled8.ipynb
# 	Untitled9.ipynb
# 	utils.py
# 	VerticleLines.JPG
# 	Visualization Challenge - Data cleaning & validation-Copy1.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy2.ipynb
# 	Visualization Challenge - Data cleaning & validation.ipynb
# 	weather.sql
# 	WELLCOME.zip
# 	WELLCOME_APCspend2013_forThinkful.csv
# 	yelp_labelled.txt

# %%
import os
 
rootDir = '.'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
    # Remove the first entry in the list of sub-directories
    # if there are any sub-directories present
    if len(subdirList) > 0:
        del subdirList[0]
# Out:
# Found directory: .
# 	.DS_Store
# 	0A32eTdBKayjCWhZqDOQ.asm
# 	0A32eTdBKayjCWhZqDOQ.bytes
# 	0ACDbR5M3ZhBJajygTuf.asm
# 	0ACDbR5M3ZhBJajygTuf.bytes
# 	2006.csv.bz2
# 	2008.csv
# 	2008.csv.bz2
# 	2013-10-01_capture-win12.netflow.csv
# 	2013-10-01_capture-win8.netflow.csv
# 	2015-07-28_mixed.binetflow.before.cvs.infection
# 	2015-09-08_mixed.binetflow.after.csv
# 	2015-09-08_mixed.binetflow.after.htm
# 	2015-09-08_mixed.binetflow.before.csv
# 	2015-09-08_mixed.binetflow.before.htm
# 	2015-09-08_mixed.binetflow.CSV
# 	A B Tests.ipynb
# 	Aggregating_and_grouping.ipynb
# 	Airline Arrivals.ipynb
# 	amazon_cells_labelled.txt
# 	APCspend2013.csv
# 	Bias and A A Testing.ipynb
# 	Bikeshare-Data.zip
# 	BikeShare.zip
# 	BOSTON_MARATHON_REVIEW.CSV
# 	botnet-capture-20110810-neris.pcap
# 	Boxes.JPG
# 	Capstone Analytic Report and Research Proposal.ipynb
# 	cat - with hidden data.bmp
# 	cat.jpg
# 	Cat_with_hidden_file.bmp
# 	Challenge
# 	Challenge - Data cleaning & Validation.ipynb
# 	Challenge - If a tree falls in the forest.ipynb
# 	Challenge - Make your own regression model - Linear Regression.ipynb
# 	Challenge - Validating a linear regression.ipynb
# 	Challenge - What model can answer this question.ipynb
# 	Challenge Advanced Regression.ipynb
# 	Challenge Boston Marathon.ipynb
# 	Challenge Evaluate an Experiment Analysis.ipynb
# 	Challenge Feedback Analysis-Copy2.ipynb
# 	Challenge Feedback Analysis.ipynb
# 	Challenge Iterate and evaluate your classifier.ipynb
# 	Challenge Make your own regression model.ipynb
# 	Challenge Model Comparison - Botnet.ipynb
# 	Challenge Preparing a Dataset for Modeling.ipynb
# 	code.zip
# 	Computer_security_data_set.csv
# 	Credit Cards.ipynb
# 	creditcard.csv
# 	creditcardfraud.zip
# 	cs448b_ipasn.csv
# 	database.sqlite
# 	dataSample.7z
# 	Dimensionality Reduction in Linear Regression.ipynb
# 	documentation.pdf
# 	Drill - Unsupervised or Supervised.ipynb
# 	Drill Fixing assumptions.ipynb
# 	Drill Formulating Good Research Questions.ipynb
# 	Drill Regression or Classification.ipynb
# 	epicurious-recipes-with-rating-and-nutrition.zip
# 	epi_r.csv
# 	fastStorage.zip
# 	Formatting_subplots_and_seaborn.ipynb
# 	Fourier Transform in Numpy.ipynb
# 	full_format_recipes.json
# 	Gradient Descent Algorithm.ipynb
# 	Guided example and challenge boosting models.ipynb
# 	Guided example and Challenge.ipynb
# 	Housing Prices.ipynb
# 	imdb_labelled.txt
# 	iris-species.zip
# 	Iris.csv
# 	Iris.ipynb
# 	Joins and CTEs.ipynb
# 	K Nearest Nieghbor Classifier.ipynb
# 	K Nearest Nieghbor Regression.ipynb
# 	K-Means.ipynb
# 	Keys.jpg
# 	Lasso Regression.ipynb
# 	lightning.JPG
# 	LoanStats3a.csv.zip
# 	LoanStats3d.csv.zip
# 	LoanStats3dd.csv
# 	melbourne-housing-market.zip
# 	MELBOURNE_HOUSE_PRICES_LESS.csv
# 	Melbourne_housing_FULL.csv
# 	Multivariable_regression-Copy1.ipynb
# 	Multivariable_regression.ipynb
# 	Other methods – mean-shift, spectral, affinity.ipynb
# 	pcapdata.py
# 	Phishing_Websites_Features.docx
# 	Phishing_website_data_set.arff
# 	Phishing_website_data_set.txt
# 	Random Forest Guided Example.ipynb
# 	Readme_file.docx
# 	recipe.py
# 	reviews_Books_5.json.gz
# 	rnd.zip
# 	sampleSubmission.csv
# 	sentiment labelled sentences.zip
# 	Sort in 60 Minutes.ipynb
# 	stations.sql
# 	status.sql
# 	Supervised Neural Nets.ipynb
# 	table_8_offenses_known_to_law_enforcement_illinois_by_city_2013.xls
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv
# 	table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls
# 	TDLAS Drill
# 	The_basics_of_plotting_review.ipynb
# 	Thinkful Random Forest Guided Example.ipynb
# 	trainLabels.csv
# 	Trees.ipynb
# 	trips.sql
# 	Tuning K Nearest Nieghbor.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled10.ipynb
# 	Untitled11.ipynb
# 	Untitled12.ipynb
# 	Untitled13.ipynb
# 	Untitled14.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
# 	Untitled5.ipynb
# 	Untitled6.ipynb
# 	Untitled7.ipynb
# 	Untitled8.ipynb
# 	Untitled9.ipynb
# 	utils.py
# 	VerticleLines.JPG
# 	Visualization Challenge - Data cleaning & validation-Copy1.ipynb
# 	Visualization Challenge - Data cleaning & validation-Copy2.ipynb
# 	Visualization Challenge - Data cleaning & validation.ipynb
# 	weather.sql
# 	WELLCOME.zip
# 	WELLCOME_APCspend2013_forThinkful.csv
# 	yelp_labelled.txt
# Found directory: .\2006.csv
# 	2006.csv
# Found directory: .\CYB642
# 	FdSig-master.zip
# Found directory: .\LoanStats3a.csv
# Found directory: .\LoanStats3d.csv
# Found directory: .\Malware Project
# 	An empirical comparison of botnet detection methods.pdf
# 	capture20110810.csv
# 	capture20110810.htm
# 	Malware Project.ipynb
# 	Untitled.ipynb
# Found directory: .\sentiment labelled sentences
# 	.DS_Store
# 	readme.txt
# Found directory: .\__MACOSX
# 	._sentiment labelled sentences
